# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url_data='https://query.data.world/s/g4e6kbwsfxqlkvwv6zupg6basrfqi7'
df=pd.read_csv(url_data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank                  173 non-null    int64
#  1   Major_code            173 non-null    int64
#  2   Major                 173 non-null    object
#  3   Major_category        173 non-null    object
#  4   Total                 173 non-null    int64
#  5   Sample_size           173 non-null    int64
#  6   Men                   173 non-null    int64
#  7   Women                 173 non-null    int64
#  8   ShareWomen            173 non-null    float64
#  9   Employed              173 non-null    int64
#  10  Full_time             173 non-null    int64
#  11  Part_time             173 non-null    int64
#  12  Full_time_year_round  173 non-null    int64
#  13  Unemployed            173 non-null    int64
#  14  Unemployment_rate     172 non-null    float64
# ...

# %%
df[['Major','Major_category']]
# Out:
#                                          Major            Major_category
# 0                        PETROLEUM ENGINEERING               Engineering
# 1               MINING AND MINERAL ENGINEERING               Engineering
# 2                    METALLURGICAL ENGINEERING               Engineering
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING               Engineering
# 4                         CHEMICAL ENGINEERING               Engineering
# ..                                         ...                       ...
# 168                                    ZOOLOGY    Biology & Life Science
# 169                     EDUCATIONAL PSYCHOLOGY  Psychology & Social Work
# 170                        CLINICAL PSYCHOLOGY  Psychology & Social Work
# 171                      COUNSELING PSYCHOLOGY  Psychology & Social Work
# 172                            LIBRARY SCIENCE                 Education
#
# [173 rows x 2 columns]

# %% [markdown]
# Renaming columns

# %%
df.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Major_category', 'Total', 'Sample_size',
#        'Men', 'Women', 'ShareWomen', 'Employed', 'Full_time', 'Part_time',
#        'Full_time_year_round', 'Unemployed', 'Unemployment_rate', 'Median',
#        'P25th', 'P75th', 'College_jobs', 'Non_college_jobs', 'Low_wage_jobs'],
#       dtype='object')

# %%
df.rename(columns={'Major':'Stream','Major_category':'Domain'},inplace=True)

# %%
df.columns=[col.lower() for col in df]

# %%
df.columns
# Out:
# Index(['rank', 'major_code', 'stream', 'domain', 'total', 'sample_size', 'men',
#        'women', 'sharewomen', 'employed', 'full_time', 'part_time',
#        'full_time_year_round', 'unemployed', 'unemployment_rate', 'median',
#        'p25th', 'p75th', 'college_jobs', 'non_college_jobs', 'low_wage_jobs'],
#       dtype='object')

# %% [markdown]
# Creating plot for visulization & Analysis

# %% [markdown]
# plot names: area,bar,barh,box,hexbin,hist,density,pie,line,heatmap

# %%
df.plot(kind='scatter',x='employed',y='unemployed',title='Employed vs Unemployed Streamwise')
# Out:
# <AxesSubplot: title={'center': 'Employed vs Unemployed Streamwise'}, xlabel='employed', ylabel='unemployed'>

# %%
df.plot(
    x='rank',
    y=['p25th','median','p75th'],
    title='Rank vs Income'
    )
# Out:
# <AxesSubplot: title={'center': 'Rank vs Income'}, xlabel='rank'>

# %% [markdown]
# Q) how many peoples are earning in given range

# %%
med=df['median']
med.plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
medi=(
    df['median']
    )

# %%
df.plot(
    kind='bar',
    x='stream',
    y='median'
)
# Out:
# <AxesSubplot: xlabel='stream'>

# %%
top_dom=df.sort_values(by='median',ascending=False)

# %%
top_dom[(top_dom['median']>=70000)]
# Out:
#    rank  major_code                                     stream       domain  \
# 0     1        2419                      PETROLEUM ENGINEERING  Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING  Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING  Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING  Engineering
#
#    total  sample_size   men  women  sharewomen  employed  ...  part_time  \
# 0   2339           36  2057    282    0.120564      1976  ...        270
# 1    756            7   679     77    0.101852       640  ...        170
# 2    856            3   725    131    0.153037       648  ...        133
# 3   1258           16  1123    135    0.107313       758  ...        150
#
#    full_time_year_round  unemployed  unemployment_rate  median  p25th   p75th  \
# 0                  1207          37           0.018381  110000  95000  125000
# ...

# %%
df
# Out:
#      rank  major_code                                     stream  \
# 0       1        2419                      PETROLEUM ENGINEERING
# 1       2        2416             MINING AND MINERAL ENGINEERING
# 2       3        2415                  METALLURGICAL ENGINEERING
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                       CHEMICAL ENGINEERING
# ..    ...         ...                                        ...
# 168   169        3609                                    ZOOLOGY
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170   171        5202                        CLINICAL PSYCHOLOGY
# 171   172        5203                      COUNSELING PSYCHOLOGY
# 172   173        3501                            LIBRARY SCIENCE
#
#                        domain  total  sample_size    men  women  sharewomen  \
# 0                 Engineering   2339           36   2057    282    0.120564
# ...

# %%
top_dom[(top_dom['median']>=70000)].plot(kind='barh',x='stream',y='median')
# Out:
# <AxesSubplot: ylabel='stream'>

# %% [markdown]
# Q) find wheter the domains which are top earners(median wise) have proprtionate distribution of genders or not?
